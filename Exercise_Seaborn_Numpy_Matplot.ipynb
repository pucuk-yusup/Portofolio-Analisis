# %%
print("Hello, Jupyter! 🚀")
# Out:
# Hello, Jupyter! 🚀

# %%
# Install library (kalau belum terinstall)
# !pip install numpy seaborn matplotlib pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 653.6 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.8 MB 787.7 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/1.8 MB 1.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.8 MB 1.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.8 MB 1.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.8 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:02
# ...

# %%
# Import pustaka
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

# %%
# Cek versi library untuk memastikan semuanya terinstall
print("NumPy Version:", np.__version__)
print("Seaborn Version:", sns.__version__)
print("Matplotlib Version:", matplotlib.__version__)
# Out:
# NumPy Version: 1.26.4
# Seaborn Version: 0.13.2
# Matplotlib Version: 3.9.0

# %%
# Buat array dengan NumPy
arr = np.random.randint(1, 100, (10,))  # 10 angka random
print("Array Random NumPy:", arr)
# Out:
# Array Random NumPy: [20 36 33 46 26 96 90 44  8 82]

# %%
# Visualisasi Data dengan Seaborn
df = sns.load_dataset("penguins")  # Load dataset contoh
sns.histplot(df['flipper_length_mm'].dropna(), kde=True, bins=20)
plt.title("Distribusi Panjang Flipper Penguin")
plt.show()

# %%
# Plot Sederhana dengan Matplotlib
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label="Sin(x)")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.legend()
plt.title("Grafik Sukses dengan Matplotlib")
plt.show()
